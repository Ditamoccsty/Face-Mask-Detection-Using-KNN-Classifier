# %%
from PIL import Image
import os, sys
import cv2
import numpy as np
from numpy import asarray
import csv

# %%
#Useful function
def createFileList(myDir, format='.png'):
    fileList = []
    print(myDir)
    
    for root, dirs, files in os.walk(myDir, topdown=False):
        for name in files:
            if name.endswith(format):
                fullName = os.path.join(root, name)
                fileList.append(fullName)
    return fileList

# %%
# load the original image
myFileList = createFileList('C:/Users/ACER/FINAL/database/nomask/')

for file in myFileList:
    print(file)
    img_file = Image.open(file)
    # img_file.show()

    # get original image parameters...
    width, height = img_file.size
    format = img_file.format
    mode = img_file.mode

    # Make image Greyscale
    img_grey = img_file.convert('L')
    #img_grey.save('result.png')
    #img_grey.show()

    # Save Greyscale values
    value = np.asarray(img_grey.getdata(), dtype=np.int).reshape((img_grey.size[1], img_grey.size[0]))
    value = value.flatten()
    print(value)
    with open("nomask.csv", 'a') as f:
        writer = csv.writer(f)
        writer.writerow(value)
# Out:
# C:/Users/ACER/FINAL/database/nomask/
# C:/Users/ACER/FINAL/database/nomask/0.png
# [233 232 230 ... 147 148 148]
# C:/Users/ACER/FINAL/database/nomask/1.png
# [221 222 224 ... 127 127 126]
# C:/Users/ACER/FINAL/database/nomask/10.png
# [218 219 219 ... 122 124 124]
# C:/Users/ACER/FINAL/database/nomask/100.png
# [198 197 198 ...  80  83  90]
# C:/Users/ACER/FINAL/database/nomask/101.png
# [198 197 198 ...  80  83  90]
# C:/Users/ACER/FINAL/database/nomask/102.png
# [213 213 212 ...  99 100 104]
# C:/Users/ACER/FINAL/database/nomask/103.png
# [201 201 202 ...  33  29  24]
# C:/Users/ACER/FINAL/database/nomask/104.png
# [ 27  26  28 ... 122 122 123]
# C:/Users/ACER/FINAL/database/nomask/105.png
# [ 25  25  32 ... 131 131 132]
# C:/Users/ACER/FINAL/database/nomask/106.png
# [156 140 127 ... 146 146 146]
# C:/Users/ACER/FINAL/database/nomask/107.png
# [154 149 135 ... 151 151 152]
# C:/Users/ACER/FINAL/database/nomask/108.png
# [ 66  58  56 ... 141 143 143]
# ...

# %%
#import pandas as pd

# %%
directory = 'C:\\Users\\ACER\FINAL\\model_dataset\\'
filename = input('Enter your name: ')
# Out:
# Enter your name: nomask

# %%
# First read into csv with pandas
data_img = np.genfromtxt("C:/Users/ACER/FINAL/nomask.csv", delimiter=",")
 # Save numpy as npy
np.save(directory+filename+'.npy', data_img)
